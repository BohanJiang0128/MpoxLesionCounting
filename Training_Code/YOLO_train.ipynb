# %%
from ultralytics import YOLO
import cv2 as cv
import random
import numpy as np

# %%
# model = YOLO("yolov8x-seg.pt")  # load a pretrained model (recommended for training)
# model1 = YOLO('runs/segment/train2/weights/best.pt')
# model2 = YOLO('leave-051301-n-100/weights/best.pt')

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/213.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/221.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/227.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/236.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/238.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/239.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/247.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/248.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/051301.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/051302.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/051307.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/051308.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/051309.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/051310.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/Kole1.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/Kole2.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/Kole3.yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)
model.train(data='YAML Files/MPX subject coming from Dekese (Not enrolled).yaml', epochs=100, imgsz=640)
success = model.export(format="onnx")

# %%
# pred = model('test_data/051301 D2_06.png')
# print(len(pred[0].masks[:,2]))
# image_gt = cv.imread('test_data/051301 D2_06.png')
# image_pred = image_gt.copy()

# mask_gt = cv.imread('ground_truth/051301/051301 D2_06_WH_gt.png')
# image_gt[:, :, 0][mask_gt[:, :, 1] > 0] = 0
# image_gt[:, :, 1][mask_gt[:, :, 1] > 0] = 255
# image_gt[:, :, 2][mask_gt[:, :, 1] > 0] = 0
# for i in range(len(pred[0].masks)):
#     msk = pred[0].masks[i,0].cpu().numpy()
# #     scr = pred[0].conf[i].cpu().numpy()
#     box = pred[0].boxes[i].cpu().numpy()
# #     if scr > 0.5:
#     image_pred[:, :, 0][msk > 0.5] = 255
#     image_pred[:, :, 1][msk > 0.5] = 0
#     image_pred[:, :, 2][msk > 0.5] = 0
# cv.imwrite('result1.png', np.hstack([image_gt,image_pred]))

# %%
# mask_gt = cv.imread('ground_truth/051301/051301 D2_06_WH_gt.png')
# image_gt = cv.imread('test_data/051301 D2_06.png')
# image_gt[:, :, 0][mask_gt[:, :, 1] > 0] = 0
# image_gt[:, :, 1][mask_gt[:, :, 1] > 0] = 255
# image_gt[:, :, 2][mask_gt[:, :, 1] > 0] = 0

# result1 = model2('test_data/051301 D2_06.png')
# res_plotted1 = result1[0].plot(conf = True, labels = False, boxes = False)
# cv.imwrite("result1_0.png", np.hstack([image_gt,res_plotted1]))

# result1 = model1('test_data/051301 D2_06.png')
# res_plotted1 = result1[0].plot(conf = True, labels = False, boxes = False)
# cv.imwrite("result1_1.png",  np.hstack([image_gt,res_plotted1]))
# Out:
# image 1/1 C:\Users\jiangb\Desktop\221005_Monkeypox_MaskRCNN\test_data\051301 D2_06.png: 640x480 35 lesions, 85.1ms
# Speed: 1.0ms preprocess, 85.1ms inference, 18.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jiangb\Desktop\221005_Monkeypox_MaskRCNN\test_data\051301 D2_06.png: 640x480 29 lesions, 604.5ms
# Speed: 0.0ms preprocess, 604.5ms inference, 11.0ms postprocess per image at shape (1, 3, 640, 640)
# True

# %%
# mask_gt = cv.imread('ground_truth/051301/051301 D2_07_WH_gt.png')
# image_gt = cv.imread('test_data/051301 D2_07.png')
# image_gt[:, :, 0][mask_gt[:, :, 1] > 0] = 0
# image_gt[:, :, 1][mask_gt[:, :, 1] > 0] = 255
# image_gt[:, :, 2][mask_gt[:, :, 1] > 0] = 0

# result2 = model2('test_data/051301 D2_07.png')
# res_plotted2 = result2[0].plot(conf = True, labels = False, boxes = False)
# cv.imwrite("result2_0.png", np.hstack([image_gt,res_plotted2]))

# result2 = model1('test_data/051301 D2_07.png')
# res_plotted2 = result2[0].plot(conf = True, labels = False, boxes = False)
# cv.imwrite("result2_1.png", np.hstack([image_gt,res_plotted2]))
# Out:
# image 1/1 C:\Users\jiangb\Desktop\221005_Monkeypox_MaskRCNN\test_data\051301 D2_07.png: 640x480 58 lesions, 80.5ms
# Speed: 1.0ms preprocess, 80.5ms inference, 29.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jiangb\Desktop\221005_Monkeypox_MaskRCNN\test_data\051301 D2_07.png: 640x480 66 lesions, 631.1ms
# Speed: 1.0ms preprocess, 631.1ms inference, 17.9ms postprocess per image at shape (1, 3, 640, 640)
# True

# %%
# mask_gt = cv.imread('ground_truth/051301/051301 D2_08_WH_gt.png')
# image_gt = cv.imread('test_data/051301 D2_08.png')
# image_gt[:, :, 0][mask_gt[:, :, 1] > 0] = 0
# image_gt[:, :, 1][mask_gt[:, :, 1] > 0] = 255
# image_gt[:, :, 2][mask_gt[:, :, 1] > 0] = 0

# result3 = model2('test_data/051301 D2_08.png')
# res_plotted3 = result3[0].plot(conf = True, labels = False, boxes = False)
# cv.imwrite("result3_0.png", np.hstack([image_gt,res_plotted3]))

# result3 = model1('test_data/051301 D2_08.png')
# res_plotted3 = result3[0].plot(conf = True, labels = False, boxes = False)
# cv.imwrite("result3_1.png", np.hstack([image_gt,res_plotted3]))
# Out:
# image 1/1 C:\Users\jiangb\Desktop\221005_Monkeypox_MaskRCNN\test_data\051301 D2_08.png: 480x640 20 lesions, 95.4ms
# Speed: 1.0ms preprocess, 95.4ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jiangb\Desktop\221005_Monkeypox_MaskRCNN\test_data\051301 D2_08.png: 480x640 21 lesions, 637.5ms
# Speed: 0.8ms preprocess, 637.5ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
# True

# %%
# mask_gt = cv.imread('ground_truth/051301/051301 D8_02_WH_gt.png')
# image_gt = cv.imread('test_data/051301 D8_02.png')
# image_gt[:, :, 0][mask_gt[:, :, 1] > 0] = 0
# image_gt[:, :, 1][mask_gt[:, :, 1] > 0] = 255
# image_gt[:, :, 2][mask_gt[:, :, 1] > 0] = 0

# result4 = model2('test_data/051301 D8_02.png')
# res_plotted4 = result4[0].plot(conf = True, labels = False, boxes = False)
# cv.imwrite("result4_0.png", np.hstack([image_gt,res_plotted4]))

# result4 = model1('test_data/051301 D8_02.png')
# res_plotted4 = result4[0].plot(conf = True, labels = False, boxes = False)
# cv.imwrite("result4_1.png", np.hstack([image_gt,res_plotted4]))
# Out:
# image 1/1 C:\Users\jiangb\Desktop\221005_Monkeypox_MaskRCNN\test_data\051301 D8_02.png: 480x640 66 lesions, 92.8ms
# Speed: 0.0ms preprocess, 92.8ms inference, 20.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\jiangb\Desktop\221005_Monkeypox_MaskRCNN\test_data\051301 D8_02.png: 480x640 68 lesions, 595.0ms
# Speed: 1.0ms preprocess, 595.0ms inference, 18.9ms postprocess per image at shape (1, 3, 640, 640)
# True
